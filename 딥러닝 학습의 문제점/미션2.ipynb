# %% [markdown]
# 실습
# 규제와 드롭 아웃을 적용할 모델을 자유롭게 생성합니다. 드롭 아웃 레이어의 경우 보통 마지막 히든층과 출력층 사이에 하나만 추가합니다.
#
# 모델을 불러온 후 학습시키고 테스트 데이터에 대해 평가합니다.
#
# 모델에 대해 손실 함수(loss function), 최적화(optimize) 알고리즘, 평가 방법(metrics)은 다음과 같이 설정합니다.
# - 손실 함수(loss) : ‘sparse_categorical_crossentropy’
# - 최적화 알고리즘(optimizer) : ‘adam’
# - 평가 방법(metrics): [‘accuracy’]
#
# 모델을 자유롭게 생성하고, 규제와 드롭 아웃을 적용해서 모델의 정확도를 87% 이상, 즉 accuracy_develop 값을 0.87 이상으로 만들어보세요.

# %%
import numpy as np
import tensorflow as tf
from visual import *
from plotter import *
from dataloader import load_data

import logging, os
logging.disable(logging.WARNING)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

np.random.seed(100)
tf.random.set_seed(100)

'''
1. 입력층과 출력층은 그대로 사용합니다.
'''

def Develop():
    
    model = tf.keras.Sequential([
                  tf.keras.layers.Flatten(input_shape=(28, 28)),
                  None,
                  tf.keras.layers.Dense(10, activation='softmax')
                  ])
    
    return model
    
    
'''
2. 모델을 불러온 후 학습시키고 테스트 데이터에 대해 평가합니다.

   Step01. Develop 함수를 이용해 두 모델을 불러옵니다.
   
   Step02. 모델의 손실 함수, 최적화 알고리즘, 평가 방법을 설정합니다.
   
   Step03. 모델의 구조를 확인하는 코드를 작성합니다.
   
   Step04. 모델을 학습시킵니다. 두 모델 모두 'epochs'는 20,
           'batch_size'는 500으로 설정합니다. 검증용 데이터도 설정해주세요.
   
   Step05. 모델을 테스트하고 accuracy 점수를 출력합니다. 
           모델의 성능을 확인해보고, 목표값을 달성해보세요.
'''

def main():
    
    # Fashion-MNIST 데이터를 불러오고 전처리하는 부분입니다.
    (train_images, train_labels), (test_images, test_labels) = load_data()
    
    train_images = train_images / 255.0
    test_images = test_images / 255.0
    
    develop_model = None
    
    develop_model.compile(None)
    
    None
    
    history = None
    
    scores = None
    
    print('\naccuracy_develop: ', scores[-1])
    
    Visulaize([('Develop', history)])
    
    return history

if __name__ == "__main__":
    main()

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
#from visual import *
#from plotter import *
#from dataloader import load_data

import logging, os
logging.disable(logging.WARNING)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

np.random.seed(100)
tf.random.set_seed(100)

'''
1. 입력층과 출력층은 그대로 사용합니다.
'''

def Develop1():
    
    model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                 tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(32, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(10, activation='softmax')])
    
    return model

# dropout 추가
def Develop2():
    
    model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                 tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(32, activation=tf.nn.relu),
                                 tf.keras.layers.Dropout(0.01),
                                 tf.keras.layers.Dense(10, activation='softmax')])
    
    return model

# batch normalization 추가
def Develop3():
    
    model = tf.keras.Sequential([tf.keras.layers.Flatten(input_shape=(28, 28)),
                                 tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                 tf.keras.layers.BatchNormalization(),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.Dense(64, activation=tf.nn.relu),
                                 tf.keras.layers.BatchNormalization(),
                                 tf.keras.layers.Dense(32, activation=tf.nn.relu),
                                 tf.keras.layers.BatchNormalization(),
                                 tf.keras.layers.Dense(10, activation='softmax')])
    
    return model
    
    
'''
2. 모델을 불러온 후 학습시키고 테스트 데이터에 대해 평가합니다.

   Step01. Develop 함수를 이용해 두 모델을 불러옵니다.
   
   Step02. 모델의 손실 함수, 최적화 알고리즘, 평가 방법을 설정합니다.
   
   Step03. 모델의 구조를 확인하는 코드를 작성합니다.
   
   Step04. 모델을 학습시킵니다. 두 모델 모두 'epochs'는 20,
           'batch_size'는 500으로 설정합니다. 검증용 데이터도 설정해주세요.
   
   Step05. 모델을 테스트하고 accuracy 점수를 출력합니다. 
           모델의 성능을 확인해보고, 목표값을 달성해보세요.
'''


# Fashion-MNIST 데이터를 불러오고 전처리하는 부분입니다.
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

develop1_model = Develop1()
develop2_model = Develop2()
develop3_model = Develop3()

develop1_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
develop2_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
develop3_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

develop1_model.summary()
develop2_model.summary()
develop3_model.summary()

train_labels_df = pd.DataFrame(train_labels)
test_labels_df = pd.DataFrame(test_labels)

history1 = develop1_model.fit(train_images, train_labels_df, epochs=50, batch_size=500, validation_data=(test_images, test_labels_df))
history2 = develop2_model.fit(train_images, train_labels_df, epochs=50, batch_size=500, validation_data=(test_images, test_labels_df))
history3 = develop3_model.fit(train_images, train_labels_df, epochs=50, batch_size=500, validation_data=(test_images, test_labels_df))

scores1 = develop1_model.evaluate(test_images, test_labels_df)
scores2 = develop2_model.evaluate(test_images, test_labels_df)
scores3 = develop3_model.evaluate(test_images, test_labels_df)


print('\naccuracy_develop1: ', scores1[-1])
print('\naccuracy_develop2: ', scores2[-1])
print('\naccuracy_develop3: ', scores3[-1])
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_12 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,466 (466.66 KB)
#  Trainable params: 119,466 (466.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_13 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_80 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_81 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_82 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,466 (466.66 KB)
#  Trainable params: 119,466 (466.66 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_14 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_83 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_84 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_85 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_86 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 116,202 (453.91 KB)
#  Trainable params: 115,754 (452.16 KB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5935 - loss: 1.2086 - val_accuracy: 0.8263 - val_loss: 0.5000
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.4678 - val_accuracy: 0.8439 - val_loss: 0.4461
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8567 - loss: 0.4121 - val_accuracy: 0.8539 - val_loss: 0.4180
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8653 - loss: 0.3813 - val_accuracy: 0.8586 - val_loss: 0.4016
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3536 - val_accuracy: 0.8632 - val_loss: 0.3886
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8794 - loss: 0.3367 - val_accuracy: 0.8633 - val_loss: 0.3886
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8818 - loss: 0.3282 - val_accuracy: 0.8571 - val_loss: 0.3952
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8865 - loss: 0.3150 - val_accuracy: 0.8625 - val_loss: 0.3782
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8900 - loss: 0.3008 - val_accuracy: 0.8649 - val_loss: 0.3753
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8936 - loss: 0.2893 - val_accuracy: 0.8689 - val_loss: 0.3622
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8984 - loss: 0.2781 - val_accuracy: 0.8720 - val_loss: 0.3499
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.2678 - val_accuracy: 0.8771 - val_loss: 0.3364
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9050 - loss: 0.2581 - val_accuracy: 0.8777 - val_loss: 0.3398
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9083 - loss: 0.2498 - val_accuracy: 0.8776 - val_loss: 0.3375
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9107 - loss: 0.2426 - val_accuracy: 0.8796 - val_loss: 0.3396
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9130 - loss: 0.2370 - val_accuracy: 0.8787 - val_loss: 0.3420
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9134 - loss: 0.2329 - val_accuracy: 0.8798 - val_loss: 0.3395
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9159 - loss: 0.2261 - val_accuracy: 0.8779 - val_loss: 0.3466
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9187 - loss: 0.2216 - val_accuracy: 0.8822 - val_loss: 0.3379
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9187 - loss: 0.2161 - val_accuracy: 0.8846 - val_loss: 0.3351
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9215 - loss: 0.2111 - val_accuracy: 0.8823 - val_loss: 0.3439
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9222 - loss: 0.2088 - val_accuracy: 0.8826 - val_loss: 0.3513
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9244 - loss: 0.2032 - val_accuracy: 0.8805 - val_loss: 0.3621
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9255 - loss: 0.2006 - val_accuracy: 0.8765 - val_loss: 0.3723
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9259 - loss: 0.1969 - val_accuracy: 0.8811 - val_loss: 0.3629
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.1937 - val_accuracy: 0.8807 - val_loss: 0.3761
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.1918 - val_accuracy: 0.8790 - val_loss: 0.3893
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.1868 - val_accuracy: 0.8824 - val_loss: 0.3871
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9294 - loss: 0.1855 - val_accuracy: 0.8822 - val_loss: 0.3797
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9307 - loss: 0.1813 - val_accuracy: 0.8822 - val_loss: 0.3757
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1795 - val_accuracy: 0.8793 - val_loss: 0.3870
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9313 - loss: 0.1816 - val_accuracy: 0.8823 - val_loss: 0.3683
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1860 - val_accuracy: 0.8798 - val_loss: 0.3812
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9329 - loss: 0.1781 - val_accuracy: 0.8803 - val_loss: 0.3799
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9358 - loss: 0.1735 - val_accuracy: 0.8792 - val_loss: 0.3968
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9368 - loss: 0.1688 - val_accuracy: 0.8764 - val_loss: 0.4013
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9383 - loss: 0.1657 - val_accuracy: 0.8765 - val_loss: 0.3917
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.1645 - val_accuracy: 0.8801 - val_loss: 0.3824
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9386 - loss: 0.1633 - val_accuracy: 0.8788 - val_loss: 0.3851
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9389 - loss: 0.1602 - val_accuracy: 0.8742 - val_loss: 0.4021
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9389 - loss: 0.1630 - val_accuracy: 0.8733 - val_loss: 0.3997
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9383 - loss: 0.1627 - val_accuracy: 0.8662 - val_loss: 0.4124
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9395 - loss: 0.1621 - val_accuracy: 0.8620 - val_loss: 0.4308
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9388 - loss: 0.1625 - val_accuracy: 0.8612 - val_loss: 0.4463
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9391 - loss: 0.1617 - val_accuracy: 0.8604 - val_loss: 0.4454
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9390 - loss: 0.1628 - val_accuracy: 0.8621 - val_loss: 0.4528
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1540 - val_accuracy: 0.8671 - val_loss: 0.4328
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1531 - val_accuracy: 0.8724 - val_loss: 0.4419
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9440 - loss: 0.1489 - val_accuracy: 0.8741 - val_loss: 0.4354
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9438 - loss: 0.1489 - val_accuracy: 0.8773 - val_loss: 0.4287
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5608 - loss: 1.2266 - val_accuracy: 0.8145 - val_loss: 0.5272
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.4960 - val_accuracy: 0.8337 - val_loss: 0.4636
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8501 - loss: 0.4274 - val_accuracy: 0.8434 - val_loss: 0.4321
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8609 - loss: 0.3878 - val_accuracy: 0.8615 - val_loss: 0.3916
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.3542 - val_accuracy: 0.8648 - val_loss: 0.3798
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.3362 - val_accuracy: 0.8693 - val_loss: 0.3680
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8824 - loss: 0.3218 - val_accuracy: 0.8711 - val_loss: 0.3542
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8885 - loss: 0.3050 - val_accuracy: 0.8720 - val_loss: 0.3489
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8907 - loss: 0.2956 - val_accuracy: 0.8724 - val_loss: 0.3475
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.2887 - val_accuracy: 0.8705 - val_loss: 0.3502
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8964 - loss: 0.2803 - val_accuracy: 0.8706 - val_loss: 0.3489
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8986 - loss: 0.2730 - val_accuracy: 0.8739 - val_loss: 0.3443
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 0.2656 - val_accuracy: 0.8662 - val_loss: 0.3613
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9039 - loss: 0.2600 - val_accuracy: 0.8733 - val_loss: 0.3447
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9078 - loss: 0.2483 - val_accuracy: 0.8755 - val_loss: 0.3445
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9094 - loss: 0.2426 - val_accuracy: 0.8776 - val_loss: 0.3401
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9122 - loss: 0.2349 - val_accuracy: 0.8762 - val_loss: 0.3411
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9148 - loss: 0.2289 - val_accuracy: 0.8792 - val_loss: 0.3350
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9165 - loss: 0.2257 - val_accuracy: 0.8802 - val_loss: 0.3301
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9184 - loss: 0.2204 - val_accuracy: 0.8824 - val_loss: 0.3265
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9181 - loss: 0.2192 - val_accuracy: 0.8801 - val_loss: 0.3368
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9203 - loss: 0.2179 - val_accuracy: 0.8781 - val_loss: 0.3436
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9219 - loss: 0.2124 - val_accuracy: 0.8773 - val_loss: 0.3547
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.2120 - val_accuracy: 0.8790 - val_loss: 0.3511
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9240 - loss: 0.2083 - val_accuracy: 0.8742 - val_loss: 0.3608
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9246 - loss: 0.2059 - val_accuracy: 0.8738 - val_loss: 0.3666
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9246 - loss: 0.2025 - val_accuracy: 0.8740 - val_loss: 0.3666
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9260 - loss: 0.1981 - val_accuracy: 0.8765 - val_loss: 0.3604
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.1926 - val_accuracy: 0.8744 - val_loss: 0.3729
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9284 - loss: 0.1899 - val_accuracy: 0.8733 - val_loss: 0.3826
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9288 - loss: 0.1880 - val_accuracy: 0.8746 - val_loss: 0.3778
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9312 - loss: 0.1817 - val_accuracy: 0.8724 - val_loss: 0.3834
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9333 - loss: 0.1785 - val_accuracy: 0.8705 - val_loss: 0.3984
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9345 - loss: 0.1745 - val_accuracy: 0.8638 - val_loss: 0.4240
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9335 - loss: 0.1780 - val_accuracy: 0.8711 - val_loss: 0.3979
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9361 - loss: 0.1723 - val_accuracy: 0.8733 - val_loss: 0.3992
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9365 - loss: 0.1685 - val_accuracy: 0.8754 - val_loss: 0.4036
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9401 - loss: 0.1628 - val_accuracy: 0.8756 - val_loss: 0.3980
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9384 - loss: 0.1636 - val_accuracy: 0.8818 - val_loss: 0.3936
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1678 - val_accuracy: 0.8789 - val_loss: 0.4010
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9382 - loss: 0.1642 - val_accuracy: 0.8766 - val_loss: 0.4242
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.1603 - val_accuracy: 0.8765 - val_loss: 0.4276
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.1597 - val_accuracy: 0.8726 - val_loss: 0.4345
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1559 - val_accuracy: 0.8681 - val_loss: 0.4689
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.1585 - val_accuracy: 0.8657 - val_loss: 0.4634
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1554 - val_accuracy: 0.8677 - val_loss: 0.4543
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9453 - loss: 0.1476 - val_accuracy: 0.8666 - val_loss: 0.4944
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.1431 - val_accuracy: 0.8662 - val_loss: 0.5066
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9463 - loss: 0.1438 - val_accuracy: 0.8661 - val_loss: 0.4771
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9459 - loss: 0.1437 - val_accuracy: 0.8612 - val_loss: 0.5064
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6738 - loss: 1.0592 - val_accuracy: 0.8184 - val_loss: 0.9053
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8618 - loss: 0.4058 - val_accuracy: 0.8357 - val_loss: 0.5025
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8823 - loss: 0.3380 - val_accuracy: 0.8449 - val_loss: 0.4427
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8923 - loss: 0.3017 - val_accuracy: 0.8591 - val_loss: 0.3889
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8995 - loss: 0.2790 - val_accuracy: 0.8482 - val_loss: 0.4163
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9068 - loss: 0.2611 - val_accuracy: 0.8430 - val_loss: 0.4287
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9108 - loss: 0.2485 - val_accuracy: 0.8434 - val_loss: 0.4307
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9156 - loss: 0.2344 - val_accuracy: 0.8424 - val_loss: 0.4460
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9200 - loss: 0.2231 - val_accuracy: 0.8470 - val_loss: 0.4314
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9244 - loss: 0.2111 - val_accuracy: 0.8478 - val_loss: 0.4275
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9289 - loss: 0.1993 - val_accuracy: 0.8336 - val_loss: 0.4642
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9303 - loss: 0.1942 - val_accuracy: 0.8478 - val_loss: 0.4321
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9337 - loss: 0.1823 - val_accuracy: 0.8285 - val_loss: 0.5097
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9361 - loss: 0.1770 - val_accuracy: 0.8251 - val_loss: 0.5053
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9347 - loss: 0.1785 - val_accuracy: 0.8521 - val_loss: 0.4503
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9361 - loss: 0.1749 - val_accuracy: 0.8533 - val_loss: 0.4483
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9421 - loss: 0.1597 - val_accuracy: 0.8417 - val_loss: 0.4969
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9405 - loss: 0.1620 - val_accuracy: 0.8419 - val_loss: 0.4895
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1573 - val_accuracy: 0.8311 - val_loss: 0.5163
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9445 - loss: 0.1521 - val_accuracy: 0.8334 - val_loss: 0.4998
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9484 - loss: 0.1455 - val_accuracy: 0.8237 - val_loss: 0.5468
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 0.1406 - val_accuracy: 0.8513 - val_loss: 0.4904
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9502 - loss: 0.1369 - val_accuracy: 0.8463 - val_loss: 0.4928
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9489 - loss: 0.1373 - val_accuracy: 0.8549 - val_loss: 0.4751
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1290 - val_accuracy: 0.8570 - val_loss: 0.4807
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9546 - loss: 0.1254 - val_accuracy: 0.8509 - val_loss: 0.5128
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9531 - loss: 0.1245 - val_accuracy: 0.8607 - val_loss: 0.4977
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9550 - loss: 0.1219 - val_accuracy: 0.8569 - val_loss: 0.5422
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9578 - loss: 0.1131 - val_accuracy: 0.8550 - val_loss: 0.5539
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9586 - loss: 0.1136 - val_accuracy: 0.8451 - val_loss: 0.6287
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9607 - loss: 0.1086 - val_accuracy: 0.8540 - val_loss: 0.5872
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9621 - loss: 0.1036 - val_accuracy: 0.8477 - val_loss: 0.6289
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.1019 - val_accuracy: 0.8558 - val_loss: 0.5877
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9612 - loss: 0.1034 - val_accuracy: 0.8538 - val_loss: 0.5812
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9632 - loss: 0.0992 - val_accuracy: 0.8588 - val_loss: 0.5850
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9647 - loss: 0.0965 - val_accuracy: 0.8568 - val_loss: 0.5951
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.0959 - val_accuracy: 0.8512 - val_loss: 0.6762
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.0929 - val_accuracy: 0.8449 - val_loss: 0.6995
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.0889 - val_accuracy: 0.8527 - val_loss: 0.6210
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.0891 - val_accuracy: 0.8520 - val_loss: 0.6959
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9697 - loss: 0.0832 - val_accuracy: 0.8573 - val_loss: 0.6632
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9700 - loss: 0.0848 - val_accuracy: 0.8503 - val_loss: 0.6944
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9675 - loss: 0.0890 - val_accuracy: 0.8516 - val_loss: 0.6442
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9713 - loss: 0.0798 - val_accuracy: 0.8516 - val_loss: 0.6876
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9699 - loss: 0.0826 - val_accuracy: 0.8537 - val_loss: 0.6930
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9703 - loss: 0.0809 - val_accuracy: 0.8662 - val_loss: 0.6602
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9711 - loss: 0.0780 - val_accuracy: 0.8584 - val_loss: 0.6849
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9731 - loss: 0.0730 - val_accuracy: 0.8632 - val_loss: 0.6590
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9723 - loss: 0.0755 - val_accuracy: 0.8610 - val_loss: 0.6457
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9750 - loss: 0.0690 - val_accuracy: 0.8604 - val_loss: 0.6729
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - accuracy: 0.8761 - loss: 0.4479
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8590 - loss: 0.5257
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.8617 - loss: 0.6875
#
# accuracy_develop1:  0.8773000240325928
#
# accuracy_develop2:  0.8611999750137329
#
# accuracy_develop3:  0.8604000210762024
