# %% [markdown]
# # Fashion-MNIST 실습

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

np.random.seed(100)
tf.random.set_seed(100)

'''
1. 다층 퍼셉트론 분류 모델을 만들고, 학습 방법을 설정해 
   학습시킨 모델을 반환하는 MLP 함수를 구현하세요.
   
   Step01. 다층 퍼셉트론 분류 모델을 생성합니다. 
           여러 층의 레이어를 쌓아 모델을 구성해보세요.
           
   Step02. 모델의 손실 함수, 최적화 방법, 평가 방법을 설정합니다.
   
   Step03. 모델을 학습시킵니다. epochs를 자유롭게 설정해보세요.
'''

def MLP(x_train, y_train):
    
    model = tf.keras.models.Sequential([tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                        tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                        tf.keras.layers.Dense(10, activation='softmax')
                                       ])
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model.fit(x_train, y_train, epochs=100, verbose=2)
    
    return model
    
x_train = np.loadtxt('./data/train_images.csv', delimiter =',', dtype = np.float32)
y_train = np.loadtxt('./data/train_labels.csv', delimiter =',', dtype = np.float32)
x_test = np.loadtxt('./data/test_images.csv', delimiter =',', dtype = np.float32)
y_test = np.loadtxt('./data/test_labels.csv', delimiter =',', dtype = np.float32)

# 이미지 데이터를 0~1범위의 값으로 바꾸어 줍니다.
x_train, x_test = x_train / 255.0, x_test / 255.0

model = MLP(x_train,y_train)

# 학습한 모델을 test 데이터를 활용하여 평가합니다.
loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print('\nTEST 정확도 :', test_acc)

# 임의의 3가지 test data의 이미지와 레이블값을 출력하고 예측된 레이블값 출력
predictions = model.predict(x_test)
rand_n = np.random.randint(100, size=3)

for i in rand_n:
    img = x_test[i].reshape(28,28)
    plt.imshow(img,cmap="gray")
    plt.show()

    print("Label: ", y_test[i])
    print("Prediction: ", np.argmax(predictions[i]))
# Out:
# Epoch 1/100
# 125/125 - 0s - 4ms/step - accuracy: 0.6910 - loss: 0.9162
# Epoch 2/100
# 125/125 - 0s - 1ms/step - accuracy: 0.7965 - loss: 0.5851
# Epoch 3/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8267 - loss: 0.4960
# Epoch 4/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8460 - loss: 0.4375
# Epoch 5/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8612 - loss: 0.3910
# Epoch 6/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8758 - loss: 0.3612
# Epoch 7/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8845 - loss: 0.3346
# Epoch 8/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8932 - loss: 0.3109
# Epoch 9/100
# 125/125 - 0s - 1ms/step - accuracy: 0.8980 - loss: 0.2895
# Epoch 10/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9030 - loss: 0.2787
# Epoch 11/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9062 - loss: 0.2712
# Epoch 12/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9093 - loss: 0.2549
# Epoch 13/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9128 - loss: 0.2418
# Epoch 14/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9158 - loss: 0.2319
# Epoch 15/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9195 - loss: 0.2226
# Epoch 16/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9240 - loss: 0.2044
# Epoch 17/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9348 - loss: 0.1887
# Epoch 18/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9395 - loss: 0.1722
# Epoch 19/100
# 125/125 - 0s - 1ms/step - accuracy: 0.
100
# 125/125 - 0s - 1ms/step - accuracy: 0.9778 - loss: 0.0783
# Epoch 82/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9893 - loss: 0.0295
# Epoch 83/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9950 - loss: 0.0148
# Epoch 84/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9910 - loss: 0.0267
# Epoch 85/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9858 - loss: 0.0393
# Epoch 86/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9935 - loss: 0.0176
# Epoch 87/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9915 - loss: 0.0212
# Epoch 88/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9902 - loss: 0.0272
# Epoch 89/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9762 - loss: 0.0660
# Epoch 90/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9790 - loss: 0.0692
# Epoch 91/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9965 - loss: 0.0132
# Epoch 92/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9975 - loss: 0.0098
# Epoch 93/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9975 - loss: 0.0110
# Epoch 94/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9927 - loss: 0.0203
# Epoch 95/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9958 - loss: 0.0118
# Epoch 96/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9985 - loss: 0.0092
# Epoch 97/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9980 - loss: 0.0080
# Epoch 98/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9937 - loss: 0.0231
# Epoch 99/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9825 - loss: 0.0494
# Epoch 100/100
# 125/125 - 0s - 1ms/step - accuracy: 0.9912 - loss: 0.0240
#
# TEST 정확도 : 0.9760000109672546
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# Label:  5.0
# Prediction:  5
# Label:  4.0
# Prediction:  2
# Label:  0.0
# Prediction:  0

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

np.random.seed(100)
tf.random.set_seed(100)

'''
1. 다층 퍼셉트론 분류 모델을 만들고, 학습 방법을 설정해 
   학습시킨 모델을 반환하는 MLP 함수를 구현하세요.
   
   Step01. 다층 퍼셉트론 분류 모델을 생성합니다. 
           여러 층의 레이어를 쌓아 모델을 구성해보세요.
           
   Step02. 모델의 손실 함수, 최적화 방법, 평가 방법을 설정합니다.
   
   Step03. 모델을 학습시킵니다. epochs를 자유롭게 설정해보세요.
'''

def MLP(x_train, y_train):
    
    model = tf.keras.models.Sequential([None])
    
    model.compile(None)
    
    None
    
    return model

    
x_train = np.loadtxt('./data/train_images.csv', delimiter =',', dtype = np.float32)
y_train = np.loadtxt('./data/train_labels.csv', delimiter =',', dtype = np.float32)
x_test = np.loadtxt('./data/test_images.csv', delimiter =',', dtype = np.float32)
y_test = np.loadtxt('./data/test_labels.csv', delimiter =',', dtype = np.float32)

# 이미지 데이터를 0~1범위의 값으로 바꾸어 줍니다.
x_train, x_test = x_train / 255.0, x_test / 255.0

model = MLP(x_train,y_train)

# 학습한 모델을 test 데이터를 활용하여 평가합니다.
loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print('\nTEST 정확도 :', test_acc)

# 임의의 3가지 test data의 이미지와 레이블값을 출력하고 예측된 레이블값 출력
predictions = model.predict(x_test)
rand_n = np.random.randint(100, size=3)

for i in rand_n:
    img = x_test[i].reshape(28,28)
    plt.imshow(img,cmap="gray")
    plt.show()
    plt.savefig("test.png")
    elice_utils.send_image("test.png")

    print("Label: ", y_test[i])
    print("Prediction: ", np.argmax(predictions[i]))
