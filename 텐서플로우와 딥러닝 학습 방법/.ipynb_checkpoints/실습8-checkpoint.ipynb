# %% [markdown]
# # XOR 문제

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
    
# XOR 문제를 위한 데이터 생성

training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[1],[1],[0]], "float32")

'''
1. 다층 퍼셉트론 모델을 생성합니다.
'''

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(16, input_dim=2, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

'''
2. 모델의 손실 함수, 최적화 방법, 평가 방법을 설정합니다.
'''

model.compile(loss='mse', optimizer='adam', metrics=['binary_accuracy'])

'''
3. 모델을 학습시킵니다. epochs를 자유롭게 설정해보세요.
''' 

hist = model.fit(training_data, target_data, epochs=150, verbose=2)

score = hist.history['binary_accuracy'][-1]

print('최종 정확도: ', score*100, '%')
# Out:
# Epoch 1/150
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 - 0s - 341ms/step - binary_accuracy: 1.0000 - loss: 0.2319
# Epoch 2/150
# 1/1 - 0s - 10ms/step - binary_accuracy: 0.7500 - loss: 0.2316
# Epoch 3/150
# 1/1 - 0s - 9ms/step - binary_accuracy: 0.7500 - loss: 0.2313
# Epoch 4/150
# 1/1 - 0s - 9ms/step - binary_accuracy: 0.7500 - loss: 0.2311
# Epoch 5/150
# 1/1 - 0s - 9ms/step - binary_accuracy: 1.0000 - loss: 0.2308
# Epoch 6/150
# 1/1 - 0s - 9ms/step - binary_accuracy: 1.0000 - loss: 0.2305
# Epoch 7/150
# 1/1 - 0s - 10ms/step - binary_accuracy: 1.0000 - loss: 0.2303
# Epoch 8/150
# 1/1 - 0s - 9ms/step - binary_accuracy: 1.0000 - loss: 0.2300
# Epoch 9/150
# ...
